# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy.linalg import inv

# %% [markdown]
# Selecting the dataset

# %%
salary_url = "https://raw.githubusercontent.com/contactsunny/data-science-examples/master/salaryData.csv"
salary_data = pd.read_csv(salary_url)

# %%
salary_data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x = salary_data['YearsExperience']
y = salary_data['Salary']

# %% [markdown]
# Assigning values for axios X and Y

# %%
x = salary_data.iloc[:, 0].values

# %%
y = salary_data.iloc[:, 1].values

# %% [markdown]
# Putting in into array

# %%
def get_theta(x, y):
    x_transpose = x.T  # Transpose of X
    theta = inv(x_transpose.dot(x)).dot(x_transpose).dot(y)
    return theta

# %% [markdown]
# Defining a function to calculate theta

# %%
x_b = np.c_[np.ones((30, 1)), x]

# %% [markdown]
# Add 1's on the matrix

# %%
params = get_theta(x_b, y)

# %% [markdown]
# Calculate the parameters theta0 e theta1

# %%
plt.plot(x,y, "b.")

# %%
y_teste = 25792.2 + 9449.9 * x

# %% [markdown]
# Defining a function y = theta0 + theta1*x

# %%
plt.plot(x, y, "b.")
plt.plot(x, y_teste, "r--")
